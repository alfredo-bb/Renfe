# %%
# !pip install flask

# %%
from flask import Flask

# %%
app = Flask(__name__)
@app.route("/")
def hello_world():
    return "Hola mundo"

@app.route("/fotos")
def categoria_fotos():
    return "Seccion fotos"

if __name__=="__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Jun/2021 19:42:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jun/2021 19:42:08] "GET /apple-touch-icon-precomposed.png HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Jun/2021 19:42:08] "GET /apple-touch-icon.png HTTP/1.1" 404 -
